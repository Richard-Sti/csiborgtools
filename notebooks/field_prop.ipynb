# %%
import numpy as np
import matplotlib.pyplot as plt
from h5py import File
from scipy.stats import spearmanr

import csiborgtools

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
paths = csiborgtools.read.Paths(**csiborgtools.paths_glamdring)

# d = np.load(paths.field_interpolated("SDSS", "csiborg2_main", 16817, "density", "SPH", 1024))

# %%
# survey = csiborgtools.SDSS()(apply_selection=False)
survey = csiborgtools.SDSSxALFALFA()(apply_selection=False)

# %%
simname = "manticore_2MPP_N128_DES_V1"
val, val_edist, smooth = csiborgtools.summary.read_interpolated_field(survey, simname, "density", "SPH", 1024, paths)
np.savez(f"../data/{survey.name}_{simname}_density_SPH_1024.npz", val=val, smooth_scales=smooth)
# Out:
# ...
# Reading fields: 100%|██████████| 31/31 [00:02<00:00, 14.35it/s]

# %%
val[0, :, 0].shape
# Out:
# (641409,)

# %%
val_edist[0, :, 0].shape
# Out:
# (101430,)

# %%
np.isnan(val[0, :, 0]).sum()
# Out:
# 539979

# %%
np.load("../data/SDSS_main_density_SPH_1024.npz")["val"]
# Out:
# array([[[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
# ...
